# %% [markdown]
# # Bigramas

# %% [markdown]
# A análise de bigramas básicamente serve para visualizar quais palavras aparecem frequentemente aparecem junta, sendo assim revelando combinações comuns de palavras (ou palavras compostas) e fornece insights sobre a estrutura do texto e o contexto das palavras
#
# Essa analise vai ser feitas com todo os site que nossa equipe selecionou que pode ter a ver com o nosso tema, o csv utilizado é 'dados_sites.csv'.

# %%
import csv
import nltk
from nltk import word_tokenize
from nltk.util import ngrams
from nltk.corpus import stopwords
from collections import Counter
import string
import pandas as pd

# Definir as palavras indesejadas
palavras_indesejadas = set(stopwords.words('portuguese'))

# Definir o limite de frequência mínima
limite_frequencia = 2

# Lê o arquivo CSV com a codificação correta
with open('dados_sites.csv', 'r', encoding='utf-8') as arquivo_csv:
    leitor_csv = csv.reader(arquivo_csv)
    
    # Pula o cabeçalho do CSV
    next(leitor_csv)
    
    # Lista para armazenar os bigramas relevantes
    bigramas_relevantes = []
    
    # Itera sobre as linhas do CSV
    for linha in leitor_csv:
        texto = linha[1]  # Obtém o texto da segunda coluna
        
        # Tokeniza o texto em palavras
        tokens = word_tokenize(texto)
        
        # Filtra as palavras indesejadas, remove pontuações e números
        palavras_filtradas = [palavra.lower() for palavra in tokens if palavra.lower() not in palavras_indesejadas and palavra not in string.punctuation and not any(char.isdigit() for char in palavra)]
        
        # Gera os bigramas
        bigramas = list(ngrams(palavras_filtradas, 2))
        
        # Atualiza a lista de bigramas relevantes com base no limite de frequência
        bigramas_relevantes.extend([bigrama for bigrama in bigramas if bigramas.count(bigrama) >= limite_frequencia])

# Conta a frequência dos bigramas relevantes
frequencia_bigramas = Counter(bigramas_relevantes)

# Cria o dataframe com os bigramas e suas frequências
df = pd.DataFrame.from_dict(frequencia_bigramas, orient='index', columns=['Frequência'])
df.index.names = ['Bigramas']
df.sort_values(by='Frequência', ascending=False, inplace=True)

# Configura para exibir todas as linhas do dataframe
pd.set_option('display.max_rows', None)

# %% [markdown]
# Lembrando que as stopwords foram retiradas, ou seja bigramas como (fim,semana) aparecem em conjunto pois antes eram "fim de semana"

# %%
df = df[df['Frequência'] > 30]
df
# Out:
#                                     Frequência
# Bigramas
# (exercícios, sobre)                       5294
# (festa, junina)                           4332
# (dúvidas, sobre)                          2950
# (..., exercícios)                         2843
# (guia, folha)                             2296
# (exclusivo, assinantes)                   2009
# (fim, semana)                             2004
# (faça, login)                             1975
# (salvar, artigos)                         1973
# (assine, faça)                            1973
# (recurso, exclusivo)                      1973
# (artigos, recurso)                        1973
# (assinantes, assine)                      1973
# (ler, salvar)                             1938
# (salvar, ler)                             1938
# (virada, cultural)                        1733
# (bares, noite)                            1728
# (semana, sp)                              1591
# (clique, aqui)                            1520
# (sp, shows)                               1501
# (sp, restaurantes)                        1469
# (sp, passeios)                            1408
# (teste, conhecimentos)                    1252
# (saiba, comprar)                          1250
# (show, sp)                                1249
# (sp, veja)                                1240
# (months, cookie)                          1205
# (cookie, definido)                        1200
# (folha, s.paulo)                          1175
# (ingressos, shows)                        1122
# (rita, lee)                               1090
# (dia, mães)                               1075
# (casas, shows)                            1073
# (sp, melhor)                              1065
# (moda, beleza)                            1024
# (cookie, consent)                         1006
# (categoria, ``)                           1005
# (cookies, categoria)                      1005
# (consentimento, usuário)                  1005
# (usuário, cookies)                        1005
# (gdpr, cookie)                            1000
# (plug-in, gdpr)                           1000
# (definido, plug-in)                       1000
# (sp, saiba)                                973
# (saiba, sobre)                             942
# (restaurantes, bares)                      929
# (fonte, instagram)                         924
# (veja, programação)                        919
# (grande, conquista)                        913
# (cinema, streaming)                        859
# (melhor, casa)                             852
# (casa, show)                               850
# (teatro, shows)                            842
# (streaming, restaurantes)                  840
# (shows, passeios)                          840
# (folha, guia)                              840
# (noite, teatro)                            840
# (logo, guia)                               840
# (comprar, ingressos)                       836
# (armazenar, consentimento)                 804
# (usado, armazenar)                         804
# (your, browser)                            802
# (restaurantes, conheça)                    801
# (famosos, novelas)                         800
# (·, festas)                                800
# (beleza, saúde)                            800
# (saiba, quais)                             777
# (brasil, escola)                           765
# (conhecimentos, sobre)                     750
# (you, want)                                745
# (hours, hours)                             735
# (festas, juninas)                          733
# (melhor, fim)                              709
# (reality, shows)                           704
# (passo, passo)                             703
# (fala, brasil)                             699
# (the, best)                                685
# (mostra, cinema)                           684
# (passeios, exposição)                      683
# (want, to)                                 676
# (política, privacidade)                    675
# (dia, trabalho)                            665
# (fashion, bubbles)                         651
# (história, brasil)                         626
# (email, required)                          612
# (faz, show)                                609
# (—please, choose)                          606
# (an, option—)                              606
# (choose, an)                               606
# (these, cookies)                           606
# (in, your)                                 604
# (cookie, usado)                            604
# (of, these)                                603
# (consent, cookie)                          600
# (cookie, duração)                          600
# (duração, descrição)                       600
# (shows, sp)                                592
# (δ, ×)                                     584
# (hour, hour)                               584
# (anuncia, show)                            579
# (paulo, passeios)                          578
# (centro, sp)                               565
# (paulo, ícone)                             560
# (assine, folha)                            560
# (ícone, twitter)                           560
# (tudo, sobre)                              560
# (ícone, instagram)                         560
# (achados, elo)                             560
# (folha, ícone)                             560
# (roteiros, cinema)                         560
# (passeios, crianças)                       560
# (twitter, ícone)                           560
# (guerra, mundial)                          556
# (lista, exercícios)                        555
# (faça, exercícios)                         554
# (comprar, shows)                           553
# (venda, ingressos)                         530
# (física, geografia)                        524
# (name, required)                           523
# (filosofia, física)                        522
# (história, geral)                          518
# (clique, saiba)                            515
# (restaurantes, sp)                         511
# (enem, enem)                               504
# (educação, física)                         479
# (paulo, veja)                              476
# (programação, shows)                       474
# (veja, dicas)                              467
# (veja, onde)                               466
# (música, compartilhar)                     461
# (gal, costa)                               456
# (required, email)                          456
# (onde, comer)                              446
# (carnaval, sp)                             443
# (how, many)                                443
# (is, the)                                  442
# (maio, maio)                               441
# (per, module)                              440
# (per, level)                               440
# (maio, leia)                               438
# (datas, comemorativas)                     438
# (pay, with)                                438
# (notícias, famosos)                        428
# (conhecimentos, faça)                      418
# (fazenda, enquetes)                        416
# (facebook, instagram)                      413
# (dicas, fim)                               412
# (restaurantes, dia)                        411
# (show, paulo)                              411
# (you, are)                                 410
# (the, website)                             407
# (junina, moda)                             406
# (pinterest, youtube)                       406
# (sobre, ...)                               404
# (shows, melhor)                            404
# (paulo, shows)                             403
# (twitter, pinterest)                       403
# (this, website)                            402
# (home, reality)                            402
# (out, of)                                  402
# (cookies, that)                            402
# (saúde, decoração)                         402
# (instagram, twitter)                       402
# (conheça, restaurantes)                    401
# (outros, outros)                           400
# (usados, entender)                         400
# (comportamento, stories)                   400
# (decoração, comportamento)                 400
# (shows, famosos)                           400
# (site, cookies)                            400
# (enquetes, notícias)                       400
# (melhor, experiência)                      400
# (javascript, in)                           400
# (novelas, moda)                            400
# (saúde, decor)                             400
# (decor, reflexões)                         400
# (reflexões, story)                         400
# (acompanhe, facebook)                      400
# (youtube, rss)                             400
# (rss, feed)                                400
# (feed, inscrever)                          400
# (inscrever, please)                        400
# (please, enable)                           400
# (enable, javascript)                       400
# (browser, to)                              400
# (to, submit)                               400
# (submit, the)                              400
# (the, form)                                400
# (sobre, media)                             400
# (media, kit)                               400
# (kit, anuncie)                             400
# (anuncie, contato)                         400
# (oferecer, melhor)                         400
# (novelas, festa)                           400
# (paulo, restaurantes)                      398
# (the, town)                                397
# (nota, enem)                               394
# (provas, gabaritos)                        391
# (ingressos, passeios)                      388
# (cinema, sp)                               387
# (will, be)                                 387
# (veja, comprar)                            385
# (free, trial)                              383
# (trial, class)                             381
# (sobre, história)                          380
# (resolução, ...)                           379
# (tire, dúvidas)                            370
# (to, schedule)                             370
# (schedule, free)                           370
# (best, time)                               369
# (many, hours)                              366
# (exercícios, história)                     365
# (além, disso)                              365
# (×, name)                                  365
# (geografia, brasil)                        364
# (externo, abre)                            360
# (link, externo)                            360
# (adicionar, comentário)                    358
# (aqui, saiba)                              356
# (quais, casas)                             355
# (..., ver)                                 355
# (if, you)                                  352
# (final, semana)                            349
# (veja, resolução)                          342
# (resultado, enem)                          341
# (geografia, história)                      340
# (brasil, exercícios)                       340
# (melhor, cinema)                           339
# (melhores, casas)                          338
# (ver, respostas)                           336
# (responder, ver)                           336
# (quais, melhores)                          335
# (shows, festival)                          334
# (junina, ·)                                334
# (geografia, geografia)                     326
# (fazem, show)                              326
# (e-mail, cadeado)                          324
# (representando, link)                      324
# (link, copiar)                             324
# (copiar, link)                             324
# (abre, página)                             324
# (messenger, linkedin)                      324
# (cadeado, representando)                   324
# (linkedin, e-mail)                         324
# (leia, voltar)                             324
# (facebook, whatsapp)                       324
# (voltar, compartilhe)                      324
# (ver, novamente)                           324
# (voltar, ver)                              324
# (novamente, voltar)                        324
# (compartilhe, facebook)                    324
# (voltar, voltar)                           324
# (twitter, messenger)                       324
# (whatsapp, twitter)                        324
# (banco, redações)                          323
# (zona, risco)                              318
# (ensino, médio)                            317
# (dicas, final)                             317
# (shows, lollapalooza)                      316
# (resolva, exercícios)                      316
# (regras, abnt)                             314
# (história, matemática)                     312
# (barra, funda)                             311
# (are, not)                                 309
# (respostas, nível)                         308
# (required, δ)                              308
# (matemática, português)                    307
# (religião, regras)                         306
# (saiba, onde)                              305
# ('', ``)                                   304
# (fotos, vídeos)                            304
# (passeios, conheça)                        304
# (what, is)                                 303
# (be, the)                                  301
# (cinemas, sp)                              300
# (tina, turner)                             298
# (basic, intermediate)                      297
# (intermediate, advanced)                   297
# (r, per)                                   296
# (partir, r)                                296
# (nível, resposta)                          295
# (from, brazil)                             295
# (passeios, veja)                           294
# (fonte, pinterest)                         294
# (in, case)                                 293
# (brazil, what)                             293
# (case, you)                                293
# (what, will)                               293
# (required, level)                          292
# (please, thanks)                           292
# (not, from)                                292
# (with, paypal)                             292
# (in, week)                                 292
# (hours, in)                                292
# (paypal, pay)                              292
# (timezone, in)                             292
# (required, what)                           292
# (time, required)                           292
# (best, date)                               292
# (looks, festa)                             289
# (café, manhã)                              288
# (dia, internacional)                       286
# (passeios, carnaval)                       285
# (enquete, grande)                          277
# (pessoas, deficiência)                     275
# (festas, ·)                                275
# (festival, sp)                             275
# (figurantes, ”)                            273
# (“, figurantes)                            273
# (avenida, paulista)                        273
# (trajes, típicos)                          273
# (joão, gomes)                              271
# (parque, ibirapuera)                       266
# (luan, santana)                            265
# (típicos, festa)                           261
# (in, the)                                  260
# (ideias, criativas)                        258
# (conseguir, ingressos)                     257
# (estados, unidos)                          257
# (diversão, educando)                       256
# (página, folha)                            252
# (conheça, lugares)                         252
# (of, the)                                  251
# (sistema, eleitoral)                       250
# (passeios, virada)                         242
# (sp, cinema)                               242
# (sp, têm)                                  238
# (cultural, veja)                           238
# (sp, bares)                                238
# (shows, the)                               237
# (shows, fim)                               237
# (shows, saiba)                             237
# (survival, portuguese)                     234
# (rio, janeiro)                             232
# (participante, grande)                     230
# (sobre, participante)                      230
# (dia, mundial)                             230
# (carnaval, ·)                              228
# (destaques, programação)                   225
# (portuguese, basic)                        224
# (passeios, dia)                            224
# (quer, fugir)                              224
# (estreias, sp)                             222
# (sala, paulo)                              220
# (região, oeste)                            220
# (enem, simulado)                           219
# (level, —please)                           219
# (date, required)                           219
# (thanks, δ)                                219
# (yesss, please)                            219
# (class, yesss)                             219
# (veja, atrações)                           218
# (espaços, shows)                           218
# (carnaval, veja)                           218
# (paulo, segundo)                           218
# (bia, miranda)                             215
# (tour, guiado)                             214
# (teatro, teatro)                           214
# (festa, joão)                              213
# (japan, house)                             212
# (vida, mãe)                                212
# (bom, retiro)                              210
# (exposição, sobre)                         210
# (noite, conheça)                           210
# (casa, francisca)                          208
# (redes, sociais)                           208
# (saúde, mental)                            206
# (crianças, bebês)                          204
# (sp, teatro)                               204
# (testar, conhecimentos)                    202
# (mostra, filmes)                           200
# (–, ideias)                                200
# (servir, inspiração)                       198
# (enem, provas)                             198
# (fotos, servir)                            198
# (exposição, marvel)                        198
# (junina, crianças)                         198
# (inspiração, arraiá)                       198
# (bebês, fotos)                             198
# (bate, volta)                              198
# (teatro, sp)                               198
# (chega, paulo)                             198
# (house, sp)                                196
# (alceu, valença)                           196
# (fotos, reprodução/pinterest)              195
# (passeios, sesc)                           194
# (mis, sp)                                  194
# (mostra, imersiva)                         192
# (chega, sp)                                192
# (consequência, “)                          191
# (passeios, museu)                          190
# (pinacoteca, contemporânea)                190
# (galerias, arte)                           190
# (semana, conheça)                          190
# (passeios, vai)                            190
# (sp, mostra)                               190
# (segunda, guerra)                          190
# (shows, paulo)                             188
# (dfb, festival)                            188
# (saúde, escola)                            187
# (música, eletrônica)                       186
# (dicas, decoração)                         186
# (morta, anos)                              185
# (comprar, ingresso)                        184
# (arnaldo, antunes)                         181
# (trabalho, docente)                        181
# (fale, produtor)                           180
# (língua, italiana)                         180
# (segundo, guia)                            179
# (capital, paulista)                        177
# (traços, místicos)                         176
# (primeira, vez)                            176
# (passarelas, dfb)                          176
# (veja, agenda)                             176
# (benzedeiras, passarelas)                  176
# (místicos, benzedeiras)                    176
# (traz, traços)                             176
# (alves, traz)                              176
# (restaurantes, veja)                       176
# (jonhson, alves)                           176
# (vanessa, mata)                            176
# (fazer, bem)                               175
# (shows, liniker)                           174
# (veja, conseguir)                          174
# (decoração, festas)                        174
# (ricarte, tudo)                            174
# (erick, ricarte)                           174
# (conheça, principais)                      172
# (vai, ganhar)                              172
# (linha, desenvolvimento)                   172
# (ingresso, shows)                          172
# (simulado, enem)                           172
# (ingressos, sp)                            172
# (aniversário, paulo)                       172
# (ingressos, venda)                         172
# (região, central)                          170
# (abadá, customizado)                       168
# (pinheiros, restaurantes)                  168
# (veja, data)                               168
# (mônica, bergamo)                          168
# (shows, joão)                              168
# (ler, matéria)                             167
# (fazem, shows)                             166
# (contact, us)                              166
# (required, your)                           166
# (sp, salvar)                               165
# (responda, exercícios)                     165
# (when, you)                                164
# (anuncia, data)                            164
# (edição, sp)                               164
# (faz, shows)                               164
# (perrengues, festival)                     164
# (destaque, ·)                              164
# (show, extra)                              164
# (cesta, páscoa)                            163
# (fazer, casa)                              163
# (junina, compartilhar)                     162
# (maria, rita)                              162
# (decoração, junina)                        162
# (sp, casa)                                 160
# (show, graça)                              160
# (login, virada)                            160
# (novas, datas)                             158
# (sp, casas)                                158
# (começam, semana)                          158
# (solange, gomes)                           158
# (resolvendo, exercícios)                   158
# (·, páscoa)                                158
# (filha, solange)                           158
# (rbd, anuncia)                             158
# (paulo, saiba)                             158
# (sp, vendas)                               158
# (lollapalooza, saiba)                      158
# (veja, evitar)                             158
# (evitar, perrengues)                       158
# (shows, rbd)                               158
# (jota, quest)                              158
# (paulo, melhor)                            158
# (wu-tang, clan)                            158
# (vendas, começam)                          158
# (chegam, cinemas)                          157
# (your, email)                              156
# (to, study)                                156
# (module, hours)                            155
# (compartilhar, virada)                     155
# (miranda, “)                               154
# (ex, bia)                                  154
# (gomes, sobre)                             154
# (–, filha)                                 154
# (“, feio)                                  154
# (conquista, –)                             154
# (feio, ”)                                  154
# (sobre, flerte)                            154
# (flerte, ex)                               154
# (to, start)                                153
# (the, training)                            153
# (week, hour)                               153
# (hours, r)                                 152
# (with, fala)                               151
# (”, “)                                     151
# (páscoa, ideias)                           150
# (blue, note)                               150
# (shows, luan)                              150
# (beleza, cuidado)                          149
# (cuidado, pessoal)                         149
# (wesley, safadão)                          149
# (or, by)                                   149
# (resolva, lista)                           148
# (level, hours)                             148
# (maio, dia)                                148
# (group, individual)                        147
# (conquista, consequência)                  147
# (”, zona)                                  147
# (free, content)                            147
# (n't, know)                                146
# (know, survival)                           146
# (advanced, select)                         146
# (select, if)                               146
# (study, per)                               146
# (level, or)                                146
# (individual, per)                          146
# (by, per)                                  146
# (module, —please)                          146
# (module, when)                             146
# (option—, i)                               146
# (start, study)                             146
# (study, with)                              146
# (brasil, how)                              146
# (week, —please)                            146
# (i, n't)                                   146
# (hour, you)                                146
# (select, class)                            146
# (card, select)                             146
# (new, class)                               146
# (class, group)                             146
# (option—, group)                           146
# (reflexões, comportamento)                 146
# (level, i)                                 146
# (i, don)                                   146
# (don, t)                                   146
# (t, know)                                  146
# (know, basic)                              146
# (advanced, timezone)                       146
# (required, how)                            146
# (hour, hours)                              146
# (thanks, pay)                              146
# (with, credit)                             146
# (credit, card)                             146
# (option—, hour)                            146
# (group, per)                               146
# (hours, you)                               146
# (get, free)                                146
# (crochê, páscoa)                           144
# (colunas, blogs)                           144
# (joão, looks)                              144
# (valença, wesley)                          143
# (santana, alceu)                           143
# (junina, sp)                               143
# (ovos, páscoa)                             142
# (moda, masculina)                          142
# (coelhinhos, artesanais)                   141
# (qualquer, outro)                          140
# (vídeos, produtos)                         140
# (nesta, aula)                              140
# (sp, servem)                               139
# (’, s)                                     139
# (teatro, musical)                          138
# (sp, conheça)                              138
# (comemorativas, hoje)                      138
# (novidades, primeira)                      138
# (produtos, saiba)                          138
# (sp, após)                                 137
# (aqui, conheça)                            137
# (abadás, masculinos)                       135
# (doenças, patologias)                      135
# (copa, mundo)                              135
# (burger, king)                             135
# (folha, melhor)                            133
# (bolsas, estudo)                           133
# (pais, professores)                        132
# (sp, café)                                 132
# (casa, natura)                             132
# (outro, espectador)                        132
# (querem, aproveitar)                       132
# (aproveitar, show)                         132
# (show, qualquer)                           132
# (carnaval, casa)                           129
# (braga, maio)                              128
# (escrito, mozuka)                          128
# (melhor, programação)                      128
# (mozuka, braga)                            128
# (lugares, comer)                           127
# (dias, responder)                          127
# (região, sul)                              126
# (restaurantes, burger)                     126
# (terra, paixão)                            126
# (origem, trajes)                           126
# (vagas, cursos)                            126
# (·, festa)                                 126
# (grande, final)                            126
# (paulista, ganha)                          126
# (cursos, workshops)                        125
# (alguns, exercícios)                       125
# (sugestões, pais)                          125
# (veja, lugares)                            125
# (visão, palco)                             124
# (veja, fotos)                              124
# (reality, show)                            124
# (encomendar, almoço)                       124
# (masculina, joão)                          123
# (central, ajuda)                           123
# (brunch, dia)                              123
# (juninas, ideias)                          122
# (correção, enem)                           121
# (confira, aqui)                            121
# (sesc, pompeia)                            121
# (almoço, páscoa)                           121
# (restaurantes, la)                         120
# (primeira, guerra)                         120
# (restaurantes, saiba)                      120
# (vitrines, festa)                          120
# (onde, encomendar)                         120
# (restaurantes, festival)                   120
# (dez, lugares)                             119
# (outro, lado)                              119
# (avaliação, folha)                         119
# (veja, restaurantes)                       118
# (nova, unidade)                            118
# (mil, pessoas)                             118
# (estreias, teatro)                         118
# (páscoa, veja)                             118
# (brasil, school)                           117
# (destes, exercícios)                       117
# (fotos, dicas)                             116
# (ganhar, dinheiro)                         116
# (cinema, compartilhar)                     116
# (joão, festa)                              116
# (menus, especiais)                         116
# (dicas, enem)                              116
# (concursos, brasil)                        115
# (junina, –)                                115
# (ranking, folha)                           115
# (marina, sena)                             115
# (mundial, café)                            114
# (mães, ·)                                  114
# (cinemas, mostra)                          114
# (paulista, sp)                             114
# (restaurantes, provar)                     114
# (–, vagas)                                 114
# (cinco, restaurantes)                      113
# (trajes, festa)                            113
# (relembre, restaurantes)                   112
# (conheça, pratos)                          112
# (portas, paulo)                            112
# (fecha, portas)                            112
# (we, coffee)                               112
# (conheça, dez)                             112
# (fartura, sp)                              112
# (unidade, avenida)                         112
# (festival, fartura)                        112
# (graça, sp)                                112
# (english, português)                       112
# (the, city)                                112
# (mcdonald, 's)                             112
# (sp, páscoa)                               112
# (restaurantes, we)                         112
# (restaurantes, bráz)                       112
# (restaurantes, natal)                      112
# (correções, provas)                        111
# (in, brazil)                               111
# (junina, simples)                          108
# (termo, adesão)                            108
# (leia, decoração)                          108
# (mapa, site)                               108
# (tendência, looks)                         108
# (fantasias, vender)                        108
# (atendimento, assinante)                   108
# (cair, clichê)                             108
# (fale, folha)                              108
# (artigos, salvos)                          108
# (usar, tendência)                          108
# (sobre, folha)                             108
# (painel, leitor)                           108
# (seminários, folha)                        108
# (matéria, compartilhe)                     107
# (cinema, estreias)                         107
# (trabalho, compartilhar)                   106
# (cultural, saiba)                          106
# (looks, carnaval)                          106
# (leia, looks)                              106
# (dicas, fazer)                             106
# (compartilhar, redes)                      106
# (mesas, páscoa)                            105
# (início, evento)                           105
# (cultural, salvar)                         105
# (mary, jane)                               104
# (dinheiro, extra)                          104
# (comemorativas, ·)                         104
# (deficiência, querem)                      104
# (avalie, conhecimentos)                    104
# (vestibular, enem)                         103
# (the, great)                               102
# (great, gatsby)                            102
# (bar, comida)                              102
# (principais, características)              102
# (vitrine, carnaval)                        102
# (veja, ...)                                101
# (camisa, xadrez)                           101
# (páscoa, –)                                100
# (carnaval, –)                              100
# (bubbles, in)                              100
# (sapato, mary)                             100
# (calçado, usar)                            100
# (sociais, ``)                              100
# (origem, calçado)                          100
# ('', salvar)                               100
# (jane, origem)                             100
# (união, europeia)                          100
# (nesta, semana)                            100
# (read, more)                                99
# (antes, início)                             99
# (horas, antes)                              99
# (cestas, páscoa)                            99
# (reino, unido)                              98
# (conhecimentos, respeito)                   98
# (acessos, sp)                               98
# (melhores, acessos)                         98
# (shows, melhores)                           98
# (denise, pitta)                             98
# (termos, políticas)                         97
# (sucesso, internet)                         96
# (mesquita, benevides)                       96
# (presentes, dia)                            96
# (junina, festa)                             96
# (fáceis, fazer)                             96
# (fazendo, sucesso)                          96
# (história, américa)                         96
# (jogos, fazendo)                            96
# (conheça, jogos)                            96
# (daniel, mesquita)                          96
# (vote, enquete)                             96
# (foto, reprodução/pinterest)                96
# (desta, lista)                              95
# (..., read)                                 95
# (horas, responder)                          95
# (música, erudita)                           94
# (primeira, edição)                          94
# (–, passo)                                  94
# (festas, infantis)                          94
# (exercícios, ...)                           94
# (clique, link)                              94
# (carnaval, carnaval)                        93
# (gatsby, party)                             93
# (--, --)                                    93
# (montar, cesta)                             93
# (sp, segundo)                               92
# (orientação, educacional)                   92
# (google, news)                              92
# (cair, folia)                               91
# (bergamo, compartilhar)                     91
# (últimas, notícias)                         90
# (ano, novo)                                 90
# (evento, saiba)                             90
# (parcele, compra)                           90
# (filmes, compartilhar)                      89
# (segundo, ranking)                          89
# (meio, destes)                              89
# (espaço, oferece)                           89
# (centro, paulo)                             88
# (termina, noivado)                          88
# (casamento, filhos)                         88
# (planos, casamento)                         88
# (após, planos)                              88
# (cunha, após)                               88
# (izabela, cunha)                            88
# (noivado, izabela)                          88
# (tabela, periódica)                         88
# (decoração, festa)                          88
# (santana, termina)                          88
# (vale, anhangabaú)                          88
# (confira, ideias)                           88
# (festas, joão)                              87
# (``, filmes)                                87
# (clique, descubra)                          85
# (então, confira)                            85
# (sala, aula)                                85
# (vitrines, dia)                             85
# (vender, presentear)                        85
# (aqui, entender)                            85
# (gosto, musical)                            85
# (novo, espaço)                              85
# (saúde, bem-estar)                          84
# (ver, matéria)                              84
# (garantir, vendas)                          84
# (casa, leia)                                84
# (fonte, reprodução/pinterest)               84
# (fazenda, votação)                          84
# (paulo, bares)                              84
# (festa, temática)                           84
# (têm, estreias)                             84
# (faça, ideias)                              84
# (with, the)                                 84
# (confira, inspirações)                      83
# (aqui, resolva)                             83
# (ensino, fundamental)                       83
# (economia, finanças)                        83
# (city, ·)                                   82
# (painel, s.a.)                              82
# (novo, bar)                                 82
# (leia, enquete)                             82
# (shows, pessoas)                            82
# (tv, folha)                                 82
# (in, english)                               82
# (confira, dicas)                            82
# (oferece, jantar)                           81
# (folha, social+)                            81
# (escuras, sp)                               81
# (boteco, escuras)                           81
# (jantar, boteco)                            81
# (passo, inspirações)                        80
# (respondendo, exercícios)                   80
# (estreias, cinema)                          80
# (·, dia)                                    79
# (dia, semana)                               79
# (volta, sp)                                 79
# (sobre, uso)                                79
# (en, español)                               78
# (compartilhe, ver)                          78
# (gastar, festa)                             78
# (hoje, terça)                               78
# (chapéu, palha)                             78
# (semana, moda)                              78
# (–, tendências)                             78
# (saiba, melhor)                             78
# (it, is)                                    77
# (veja, ideias)                              77
# (r, mil)                                    77
# (aqui, descubra)                            77
# (spfw, dia)                                 76
# (cada, gosto)                               76
# (programação, cada)                         76
# (artigo, científico)                        76
# (comemorações, joão)                        76
# (história, comemorações)                    76
# (login, saiba)                              75
# (dias, melhores)                            75
# (brasil, história)                          75
# (onde, assistir)                            75
# (cultural, compartilhar)                    75
# (compartilhar, saiba)                       75
# (estratégias, ensino-aprendizagem)          75
# (festa, wandinha)                           75
# (todo, lugar)                               75
# (vídeos, passo)                             74
# (festas, decoração)                         74
# (visual, merchandising)                     74
# (segundo, avaliação)                        74
# (melhores, ideias)                          74
# (vestir, joão)                              74
# (língua, portuguesa)                        74
# (política, educacional)                     74
# (projeto, editorial)                        74
# (–, faça)                                   74
# (comidas, típicas)                          74
# (espectador, shows)                         74
# (conhecimentos, exercícios)                 74
# (aqui, entenda)                             74
# (banco, dados)                              74
# (ideias, decoração)                         73
# (século, xix)                               73
# (r, r)                                      73
# (to, the)                                   73
# ('tudo, todo)                               73
# (s.paulo, linkedin)                         72
# (grupo, folha)                              72
# (trabalhe, folha)                           72
# (senha, conta)                              72
# (perfil, senha)                             72
# (s.paulo, twitter)                          72
# (decorar, presentear)                       72
# (twitter, link)                             72
# (clube, folha)                              72
# (linkedin, link)                            72
# (ombudsman, painel)                         72
# (s.paulo, instagram)                        72
# (folha, clube)                              72
# (instagram, link)                           72
# (página, rss)                               72
# (coleções, folha)                           72
# (rss, folha)                                72
# (mães, –)                                   72
# (folha, mapas)                              72
# (assinante, erramos)                        72
# (editar, perfil)                            72
# (conta, atendimento)                        72
# (folha, tópicos)                            72
# (tópicos, folha)                            72
# (folha, transparência)                      72
# (versão, impressa)                          72
# (moda, paulo)                               72
# (folha, in)                                 72
# (impressa, mapa)                            72
# (español, folha)                            72
# (folha, últimas)                            72
# (enquete, fazenda)                          72
# (folha, en)                                 72
# (atendimento, sair)                         72
# (edição, folha)                             72
# (casa, gastar)                              72
# (anuncie, publicidade)                      72
# (simples, dicas)                            72
# (clique, confira)                           72
# (publicidade, folha)                        72
# (folha, atendimento)                        72
# (acervo, folha)                             72
# (gostaria, receber)                         72
# (empresa, folha)                            72
# (paulo, teatro)                             72
# (salvos, newsletters)                       72
# (teatro, veja)                              72
# (folha, manhã)                              72
# (palcos, sp)                                72
# (assinatura, editar)                        72
# (manhã, s.a.)                               72
# (newsletters, assinatura)                   72
# (acesse, artigos)                           72
# (ciência, ambiente)                         72
# (copyright, folha)                          72
# (francieli, hess)                           72
# (folha, s.)                                 72
# (folha, área)                               72
# (área, personalizada)                       72
# (sidebar, menu)                             72
# (s., paulo)                                 72
# (publicidade, legal)                        72
# (estreias, semana)                          71
# (educação, infantil)                        71
# (cinema, cinema)                            71
# (vestidos, festa)                           71
# (ideias, dicas)                             70
# (geólogo, datas)                            70
# (fazenda, enquete)                          70
# (dia, geólogo)                              70
# (..., atualidades)                          70
# (salas, cinema)                             70
# (bruno, camargo)                            70
# (folha, artigos)                            70
# (jornal, folha)                             70
# (redação, enem)                             70
# (junina, história)                          70
# (sabe, sobre)                               70
# (tendências, vez)                           70
# (aqui, ler)                                 70
# (sendo, assim)                              70
# (sobre, sistema)                            69
# (veja, quais)                               69
# (glória, perez)                             68
# (giulia, gam)                               68
# (customização, abadá)                       68
# (homens, trajes)                            68
# (joão, visual)                              68
# (looks, homens)                             68
# (decoração, joão)                           68
# (mulheres, apaixonadas)                     68
# (fique, casa)                               68
# (espaço, unimed)                            68
# (customizado, –)                            68
# (junina, fotos)                             68
# (criativas, baratas)                        68
# (baratas, enfeitar)                         68
# (enfeitar, cair)                            68
# (heloísa, mulheres)                         68
# (junina, melhores)                          68
# (santo, antônio)                            68
# (joão, veja)                                68
# (·, destaque)                               68
# (presentear, páscoa)                        68
# (ideias, vestir)                            68
# (login, rita)                               68
# (uncategorized, adicionar)                  67
# (trabalho, conclusão)                       67
# (in, rio)                                   67
# (conclusão, curso)                          67
# (acesse, texto)                             67
# (descubra, quais)                           67
# (aprenda, sobre)                            67
# (email, protected)                          67
# (sp, filmes)                                67
# (inspirações, criativas)                    66
# (junina, infantil)                          66
# (ideias, diferentes)                        66
# (meio, desta)                               66
# (and, the)                                  66
# (criativas, decorar)                        66
# (enquetes, fazenda)                         66
# (principais, ...)                           66
# (conhecimentos, ...)                        66
# (provas, enem)                              66
# (quais, principais)                         66
# (show, record)                              66
# (custa, r)                                  66
# (páscoa, receitas)                          66
# (“, ”)                                      65
# (atrás, diversão)                           65
# (saiba, tudo)                               65
# (conhecimentos, resolvendo)                 65
# (folha, shows)                              64
# (compartilhar, rita)                        64
# (receitas, moldes)                          64
# (pouco, sobre)                              64
# (estudar, exterior)                         64
# (sobre, reações)                            64
# (mostra, gratuita)                          63
# (sobre, tipos)                              63
# (pequena, sereia)                           63
# (século, xx)                                63
# (vai, amar)                                 63
# (pode, fazer)                               63
# (exemplo, fonte)                            63
# ...
# (semana, cinemas)                           42
# (arrasar, quadrilha)                        42
# (reprodução, pinterest)                     42
# (cola, quente)                              42
# (clique, aprenda)                           42
# (shows, cinemas)                            42
# ('dungeons, dragons)                        42
# (decorar, casa)                             42
# (camargo, bruno)                            42
# (bruno, tálamo)                             42
# (mato, grosso)                              42
# (tálamo, natália)                           42
# (enquete, uol)                              42
# (dessa, forma)                              42
# (–, joão)                                   42
# (..., educação)                             42
# (onde, vai)                                 42
# (dez, anos)                                 42
# (vila, madalena)                            42
# (itens, podem)                              42
# (roberto, carvalho)                         42
# (tudo, sabe)                                42
# (região, leste)                             41
# (simpatias, festas)                         41
# (dia, responder)                            41
# (estampa, xadrez)                           41
# (confira, alguns)                           41
# (peças, teatro)                             41
# (pinheiros, região)                         41
# (clique, acesse)                            41
# ('os, fabelmans)                            41
# (..., curiosidades)                         41
# (veja, todos)                               41
# (veja, resultado)                           41
# (assistir, filmes)                          40
# (brasil, clique)                            40
# (filmes, mostra)                            40
# (melhorar, experiência)                     40
# (ingressos, r)                              40
# (”, famosos)                                40
# (semana, teatro)                            40
# (hora, brincar)                             40
# (espaço, itaú)                              40
# (mudanças, climáticas)                      40
# (falar, sobre)                              40
# (adam, driver)                              40
# (começa, escalações)                        40
# ('', palco)                                 40
# (fará, pausa)                               40
# (anitta, anuncia)                           40
# (hoje, veja)                                40
# (álbum, ``)                                 40
# (passar, jogo)                              40
# (bbb, antes)                                40
# (confira, tudo)                             40
# (vai, passar)                               40
# (após, carnaval)                            40
# (nasce, filho)                              40
# (sister, bbb)                               40
# ('', https)                                 40
# (fotos, sister)                             40
# (larissa, antes)                            40
# (filho, claudia)                            40
# (paulo, moda)                               40
# (antes, cirurgias)                          40
# (jarbas, mello)                             40
# (escalações, vote)                          40
# (perfeitos, shows)                          40
# (outfits, perfeitos)                        40
# (pausa, carreira)                           40
# (bbb, outfits)                              40
# (record, tv)                                40
# (história, história)                        40
# (claudia, raia)                             40
# (marvvila, bbb)                             40
# (tempo, real)                               40
# (looks, marvvila)                           40
# (raia, jarbas)                              40
# (shows, festivais)                          40
# (italiano, língua)                          39
# (university, of)                            39
# (customizar, abadá)                         39
# (fazer, festa)                              39
# (verifique, conhecimentos)                  39
# (inspirações, looks)                        39
# (sobre, energia)                            39
# (história, festa)                           39
# (dicas, estudo)                             39
# (correção, comentada)                       39
# (foto, freepik)                             39
# (melhores, universidades)                   39
# (estudo, sobre)                             39
# (sobre, estilo)                             39
# (know, the)                                 39
# (história, cultura)                         38
# (sp, leia)                                  38
# (cinemas, oscar)                            38
# (folha, filmes)                             38
# (cinema, cinemas)                           38
# (sp, estreias)                              38
# (estreias, cinemas)                         38
# (comemorativas, maio)                       38
# (oscar, estreias)                           38
# (futebol, streaming)                        38
# (ganha, sessão)                             38
# (streaming, retrospectiva)                  38
# (cemitério, automóveis)                     38
# (entrada, gratuita)                         38
# (vender, ingressos)                         38
# (unidos, direção)                           38
# (campina, grande)                           38
# (conheça, pouco)                            38
# (ana, maria)                                38
# (anexo, espaço)                             38
# (adereços, festa)                           38
# (sobre, importante)                         38
# (cinema, filmes)                            38
# (aula, falaremos)                           38
# (streaming, semana)                         38
# (maria, braga)                              38
# (indicados, oscar)                          38
# (filmes, indicados)                         38
# (destaque, streaming)                       38
# (conheça, novos)                            38
# (casa, shows)                               38
# ('gato, botas)                              38
# (vila, mariana)                             38
# (itaú, cinema)                              38
# (novos, bares)                              38
# (avaliar, conhecimentos)                    38
# (folha, cinema)                             38
# (cantora, morta)                            38
# (acessórios, carnaval)                      37
# (acordo, ortográfico)                       37
# (educando, fazer)                           37
# (sobre, movimento)                          37
# (resolvendo, ...)                           37
# (dicas, presentes)                          37
# (exame, nacional)                           37
# (conheça, cinco)                            37
# (gripe, espanhola)                          37
# (language, and)                             37
# (teste, ...)                                37
# (sobre, vida)                               37
# (fashion, week)                             36
# (sobre, tema)                               36
# (páscoa, fonte)                             36
# (língua, inglesa)                           36
# (programação, paulo)                        36
# (whitney, houston)                          36
# (neste, fim)                                36
# (agenda, teatral)                           36
# (peça, gratuita)                            36
# (joão, neon)                                36
# (portuguese, language)                      36
# (lucas, brêda)                              36
# (cada, vez)                                 36
# (..., bolsas)                               36
# (du, soleil)                                36
# (fechar, portas)                            36
# (portas, sp)                                36
# (inspira, peça)                             36
# (adriana, calcanhotto)                      36
# (one, of)                                   36
# (pandemia, teatro)                          36
# (soleil, volta)                             36
# (benevides, bares)                          36
# (cirque, du)                                36
# (leia, maio)                                36
# (agenda, teatro)                            36
# (compartilhar, leia)                        36
# (lino, villaventura)                        36
# (bares, restaurantes)                       36
# (fernanda, yamamoto)                        36
# (pinterest, fonte)                          36
# (ator, jeff)                                36
# (rey, brasil)                               36
# (del, rey)                                  36
# (lana, del)                                 36
# (celebra, anos)                             36
# (dezembro, teatro)                          36
# (passeios, musical)                         36
# (estreia, sp)                               36
# (seguida, confira)                          36
# (teatros, sp)                               36
# (teatro, musicais)                          36
# (ler, análise)                              36
# (ilustrada, musical)                        36
# (peças, ilustrada)                          36
# (sp, peça)                                  36
# (lázaro, ramos)                             36
# (municipal, sp)                             36
# (passeios, bexiga)                          36
# (musicais, cartaz)                          36
# (leva, teatro)                              36
# (começa, vender)                            36
# (teatro, 'molly)                            36
# ('molly, bloom)                             36
# (pesquisa, científica)                      36
# (..., sisu)                                 35
# (sobre, propriedades)                       35
# (clicando, aqui)                            35
# (ciências, humanas)                         35
# (aqui, conhecer)                            35
# (lei, newton)                               35
# (algumas, dicas)                            35
# (ovo, páscoa)                               35
# (junina, casa)                              35
# (descubra, sobre)                           35
# (zona, oeste)                               35
# (taxa, inscrição)                           35
# (prefeitura, paulo)                         35
# (turma, pagode)                             35
# (abolição, escravatura)                     35
# (mês, ano)                                  35
# (usuário, aderente)                         35
# (enem, lista)                               35
# (this, is)                                  35
# (jade, picon)                               35
# (vibra, espaços)                            34
# (dia, namorados)                            34
# (delivery, via)                             34
# (protetor, solar)                           34
# (notas, enem)                               34
# (volta, aulas)                              34
# (som, sp)                                   34
# (segunda, edição)                           34
# (texto, científico)                         34
# (bel, coelho)                               34
# (qualidade, vida)                           34
# (presente, dia)                             34
# (clique, teste)                             34
# (dias, maio)                                34
# (the, language)                             34
# (roça, especial)                            34
# (costa, compartilhar)                       34
# (paola, carosella)                          34
# (educação, básica)                          34
# (thiago, servo)                             34
# (conheça, casas)                            34
# (nova, andradina)                           34
# (francisca, vibra)                          34
# (desenvolvimento, infantil)                 34
# (outra, opção)                              33
# (visto, estudante)                          33
# (lgbtqia+, compartilhar)                    33
# (cursinhos, comunitários)                   33
# (responsabilidade, civil)                   33
# (sobre, primeira)                           33
# (crie, evento)                              33
# (sabrina, sato)                             33
# (foto, reprodução)                          33
# (guerra, civil)                             33
# (sobre, período)                            33
# (sistema, nervoso)                          33
# (look, festa)                               33
# (leia, texto)                               33
# (ideias, fantasias)                         33
# (decoração, páscoa)                         33
# (reprodução/pinterest, além)                33
# (sobre, segunda)                            33
# (pode, usar)                                33
# (aqui, saber)                               32
# (meses, atrás)                              32
# (cursos, online)                            32
# (rolou, último)                             32
# (museu, afro)                               32
# (cirurgias, looks)                          32
# (vai, morrer)                               32
# (show, festival)                            32
# (casas, show)                               32
# (→, canal)                                  32
# (brasil, teste)                             32
# (cultural, immersion)                       32
# (inscrição, enem)                           32
# (villaventura, confira)                     32
# (castro, festival)                          32
# ('homem-aranha, através)                    32
# (desde, janeiro)                            32
# (escolar, orientações)                      32
# (através, aranhaverso)                      32
# (goo, dolls)                                32
# (leia, grande)                              32
# (melhor, custo-benefício)                   32
# (santa, cecília)                            32
# (brasil, tudo)                              32
# (ano, dia)                                  32
# (saúde, saúde)                              32
# (sobre, governo)                            32
# (aula, grátis)                              32
# (vai, precisar)                             32
# (/h, aula)                                  32
# (r, /h)                                     32
# (conheça, opções)                           32
# (sobre, funções)                            32
# (carnaval, nasce)                           32
# (trabalhos, artesanais)                     32
# (confira, celebrações)                      32
# (the, most)                                 32
# (the, team)                                 32
# (looks, lana)                               32
# (–, decoração)                              32
# (junina, festas)                            32
# (custo-benefício, sp)                       32
# (exercício, ver)                            32
# (quinto, mês)                               32
# (yamamoto, lino)                            32
# (goo, goo)                                  32
# (dia, quinto)                               32
# (oeste, tel)                                32
# (anos, carreira)                            32
# (cultural, passeios)                        32
# (dia, dia)                                  32
# (celebrações, maio)                         32
# (elza, soares)                              32
# (menu, degustação)                          32
# (dia, fernanda)                             32
# (vídeo, s)                                  32
# (roupa, cantora)                            32
# (estilo, roupa)                             32
# (festivais, anitta)                         32
# (sexy, –)                                   31
# (termos, uso)                               31
# (passo, vídeo)                              31
# (escolas, públicas)                         31
# (xícara, chá)                               31
# (aqui, resolver)                            31
# (amigo, secreto)                            31
# (espaço, geográfico)                        31
# (confira, melhores)                         31
# (https, https)                              31
# (sobre, força)                              31
# (caipira, sexy)                             31
# (história, china)                           31
# (mercado, trabalho)                         31
# (–, vestidos)                               31
# (aulas, física)                             31
# (resultado, parcial)                        31
# (próxima, zona)                             31
# (estudo, caso)                              31

# %%
len(df)
# Out:
# 1671

# %% [markdown]
# # Insights

# %% [markdown]
# #### bigramas referente ao público-alvo
#
# 1. (brasil,escola) com frequencia de 765
#
# 2. (passeios, crianças) com frequencia de 560
#
# 3. (ensino,médio) com frequencia de 317
#
# 4. (diversão, educando) com frequencia de 256
#
# 5. (crianças, bebês) com frequencia de 204
#
# 6. (junina, crianças) com frequencia de 198
#
# 7. (bebês, fotos) com frequencia de 198
#
# 8. (ensino, fundamental) com frequencia de 83
#
#
# *Esses bigramas podem estar indicando a necessidade do nosso grupo investir em um publico-alvo mais jovem, como crianças e adolescentes visto que eles participam desses eventos frequentemente nas escolas.*

# %% [markdown]
# #### bigramas referentes a época
#
# 1. (fim, semana) com frequencia de 2004
#
# 2. (final,semana) com frequencia de 349
#
# *Esses bigramas podem indicar qual época nosso clientes buscam mais nosso produtos, podemos validar esse teória vendo a frequencia da citações sobre o tema nas redes sociais ao decorrer da semana.*

# %% [markdown]
# #### bigramas referentes a local
#
# 1. (parque, ibirapuera) com frequencia de 266
#
# *Talvez o parque ibirapuera tenha um relação com nosso público, podemos analisar a existencia de eventos e shows nessa época do ano*
